# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv("emails.csv")
df
# Out:
#                              file  \
# 0           allen-p/_sent_mail/1.
# 1          allen-p/_sent_mail/10.
# 2         allen-p/_sent_mail/100.
# 3        allen-p/_sent_mail/1000.
# 4        allen-p/_sent_mail/1001.
# ...                           ...
# 517396  zufferli-j/sent_items/95.
# 517397  zufferli-j/sent_items/96.
# 517398  zufferli-j/sent_items/97.
# 517399  zufferli-j/sent_items/98.
# 517400  zufferli-j/sent_items/99.
#
#                                                   message
# 0       Message-ID: <18782981.1075855378110.JavaMail.e...
# 1       Message-ID: <15464986.1075855378456.JavaMail.e...
# 2       Message-ID: <24216240.1075855687451.JavaMail.e...
# 3       Message-ID: <13505866.1075863688222.JavaMail.e...
# 4       Message-ID: <30922949.1075863688243.JavaMail.e...
# ...                                                   ...
# 517396  Message-ID: <26807948.1075842029936.JavaMail.e...
# 517397  Message-ID: <25835861.1075842029959.JavaMail.e...
# 517398  Message-ID: <28979867.1075842029988.JavaMail.e...
# 517399  Message-ID: <22052556.1075842030013.JavaMail.e...
# 517400  Message-ID: <28618979.1075842030037.JavaMail.e...
#
# [517401 rows x 2 columns]

# %%
a= pd.read_pickle('ys_combine.pkl')
a
# Out:
#       label                            title  \
# 0       ham  0001.2001-02-07.kitchen.ham.txt
# 1       ham  0003.2001-02-08.kitchen.ham.txt
# 2       ham  0005.2001-02-08.kitchen.ham.txt
# 3       ham  0006.2001-02-08.kitchen.ham.txt
# 4       ham  0007.2001-02-09.kitchen.ham.txt
# ...     ...                              ...
# 2250  phish                    997_False.txt
# 2251  phish                    998_False.txt
# 2252  phish                    999_False.txt
# 2253  phish                     99_False.txt
# 2254  phish                      9_False.txt
#
#                                                 content
# 0     Subject: key hr issues going forward\na ) year...
# 1     Subject: re : key hr issues going forward\nall...
# 2     Subject: epmi files protest of entergy transco...
# 3     Subject: california power 2 / 8\nplease contac...
# 4     Subject: california power 2 / 9\nthe following...
# ...                                                 ...
# 2250  Subject: IMPORTANT : Notification Of Limited A...
# 2251  Subject: Fifth Third Bank customer notificatio...
# 2252  Subject: Notice from PayPal - Identity protect...
# 2253  Subject: Notification of limited account acces...
# 2254  Subject: OFFICIAL INFORMATION FOR CLIENT OF SO...
#
# [9980 rows x 3 columns]

# %%
pd.read_pickle('resources\emails-enron.mbox-export.pkl')
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     0
# 1         False            0          False        False          True     0
# 2         False            0          False        False          True     0
# 3         False            0          False        False          True     0
# 4         False            0          False        False          True     0
# ...         ...          ...            ...          ...           ...   ...
# 1994      False            0          False        False          True     0
# 1995      False            0          False        False          True     0
# 1996      False            0          False        False          True     1
# 1997      False            0          False        False          True     0
# 1998      False            0          False        False          True     0
#
#       External Resources  Javascript  Css  IPs in URLs  @ in URLs  \
# 0                      0           0    0        False      False
# 1                      0           0    0        False      False
# 2                      0           0    0        False      False
# 3                      0           0    0        False      False
# 4                      0           0    0        False      False
# ...                  ...         ...  ...          ...        ...
# 1994                   0           0    0        False      False
# 1995                   0           0    0        False      False
# 1996                   0           0    0        False      False
# 1997                   0           0    0        False      False
# 1998                   0           0    0        False      False
#
#               Encoding label
# 0                 7bit   ham
# 1                 7bit   ham
# 2                 7bit   ham
# 3                 7bit   ham
# 4     quoted-printable   ham
# ...                ...   ...
# 1994              7bit   ham
# 1995              7bit   ham
# 1996              7bit   ham
# 1997              7bit   ham
# 1998              7bit   ham
#
# [1999 rows x 13 columns]

# %%
pd.read_pickle('resources\emails-enron.mbox-export.pkl')
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     0
# 1         False            0          False        False          True     0
# 2         False            0          False        False          True     0
# 3         False            0          False        False          True     0
# 4         False            0          False        False          True     0
# ...         ...          ...            ...          ...           ...   ...
# 4274      False            0          False        False          True     0
# 4275      False            0          False        False          True     1
# 4276      False            0          False        False          True     0
# 4277      False            0          False        False          True     0
# 4278      False            0          False        False          True     0
#
#       External Resources  Javascript  Css  IPs in URLs  @ in URLs  \
# 0                      0           0    0        False      False
# 1                      0           0    0        False      False
# 2                      0           0    0        False      False
# 3                      0           0    0        False      False
# 4                      0           0    0        False      False
# ...                  ...         ...  ...          ...        ...
# 4274                   0           0    0        False      False
# 4275                   0           0    0        False      False
# 4276                   0           0    0        False      False
# 4277                   0           0    0        False      False
# 4278                   0           0    0        False      False
#
#               Encoding  Phishy
# 0                 7bit    True
# 1                 7bit    True
# 2                 7bit    True
# 3                 7bit    True
# 4     quoted-printable    True
# ...                ...     ...
# 4274              7bit    True
# 4275              7bit    True
# 4276              7bit    True
# 4277              7bit    True
# 4278              7bit    True
#
# [4279 rows x 13 columns]

# %%
pd.read_csv('resources\emails-enron.mbox-export.csv', index_col=0)
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     0
# 1         False            0          False        False          True     0
# 2         False            0          False        False          True     0
# 3         False            0          False        False          True     0
# 4         False            0          False        False          True     0
# ...         ...          ...            ...          ...           ...   ...
# 1994      False            0          False        False          True     0
# 1995      False            0          False        False          True     0
# 1996      False            0          False        False          True     1
# 1997      False            0          False        False          True     0
# 1998      False            0          False        False          True     0
#
#       External Resources  Javascript  Css  IPs in URLs  @ in URLs  \
# 0                      0           0    0        False      False
# 1                      0           0    0        False      False
# 2                      0           0    0        False      False
# 3                      0           0    0        False      False
# 4                      0           0    0        False      False
# ...                  ...         ...  ...          ...        ...
# 1994                   0           0    0        False      False
# 1995                   0           0    0        False      False
# 1996                   0           0    0        False      False
# 1997                   0           0    0        False      False
# 1998                   0           0    0        False      False
#
#               Encoding label
# 0                 7bit   ham
# 1                 7bit   ham
# 2                 7bit   ham
# 3                 7bit   ham
# 4     quoted-printable   ham
# ...                ...   ...
# 1994              7bit   ham
# 1995              7bit   ham
# 1996              7bit   ham
# 1997              7bit   ham
# 1998              7bit   ham
#
# [1999 rows x 13 columns]

# %%
pd.read_csv('resources\phishing3.mbox-export.csv', index_col=0)
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     2
# 1         False            0          False        False          True     2
# 2         False            0          False        False          True     2
# 3         False            0          False        False          True     3
# 4         False            0          False        False          True     3
# ...         ...          ...            ...          ...           ...   ...
# 1994      False            0          False        False          True     2
# 1995      False            0          False        False          True    18
# 1996      False            0          False        False          True    18
# 1997      False            0          False        False          True     2
# 1998      False            0          False        False          True     2
#
#       External Resources  Javascript  Css  IPs in URLs  @ in URLs Encoding  \
# 0                      0           0    0         True      False     none
# 1                      0           0    0        False      False     7bit
# 2                      0           0    0        False      False     7bit
# 3                      0           0    0         True      False     8bit
# 4                      0           0    0         True      False     8bit
# ...                  ...         ...  ...          ...        ...      ...
# 1994                   0           0    0        False      False     none
# 1995                   0           0    0         True      False     7bit
# 1996                   0           0    0        False      False     none
# 1997                   0           0    0        False      False     none
# 1998                   0           0    0        False      False     none
#
#       label
# 0     phish
# 1     phish
# 2     phish
# 3     phish
# 4     phish
# ...     ...
# 1994  phish
# 1995  phish
# 1996  phish
# 1997  phish
# 1998  phish
#
# [1999 rows x 13 columns]

# %%
favorite_color = pickle.load(open('resources\phishing3.mbox-export-index.pkl', 'rb'))
favorite_color
# Out:
#         id                                            message  \
# 0        1  text/html\t<html><p><font face="Arial"><A HREF...
# 1        2  text/html\t<DIV><PRE><TT><STRONG>Dear eBay Use...
# 2        3  text/html\t<DIV>\n<DIV>\n<P>Dear valued custom...
# 3        4  text/html\t<style type="text/css">\n<!--\n.sty...
# 4        5  text/html\t<style type="text/css">\n<!--\n.sty...
# ...    ...                                                ...
# 1994  1995  text/html\t<head>\n<meta    http-equiv="Conten...
# 1995  1996  text/html\t\n\n<html><head><title></title><!--...
# 1996  1997  text/plain\teBay sent this message to user (us...
# 1997  1998  text/html\t<head>\n<meta http-equiv="Content-T...
# 1998  1999  text/html\t<p>\n\t\t\t<font face="Verdana" siz...
#
#                                                     raw
# 0     [Return-Path, Delivered-To, Received, Received...
# 1     [Return-Path, Delivered-To, Received, Received...
# 2     [Return-Path, Delivered-To, Received, Received...
# 3     [Return-Path, Delivered-To, Received, Received...
# 4     [Return-Path, Delivered-To, Received, Received...
# ...                                                 ...
# 1994  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1995  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1996  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1997  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1998  [Return-Path, X-Original-To, Delivered-To, Rec...
#
# [1999 rows x 3 columns]

# %%
pd.read_pickle('resources\phishing3.mbox-export-index.pkl')
# Out:
#         id                                            message  \
# 0        1  text/html\t<html><p><font face="Arial"><A HREF...
# 1        2  text/html\t<DIV><PRE><TT><STRONG>Dear eBay Use...
# 2        3  text/html\t<DIV>\n<DIV>\n<P>Dear valued custom...
# 3        4  text/html\t<style type="text/css">\n<!--\n.sty...
# 4        5  text/html\t<style type="text/css">\n<!--\n.sty...
# ...    ...                                                ...
# 1994  1995  text/html\t<head>\n<meta    http-equiv="Conten...
# 1995  1996  text/html\t\n\n<html><head><title></title><!--...
# 1996  1997  text/plain\teBay sent this message to user (us...
# 1997  1998  text/html\t<head>\n<meta http-equiv="Content-T...
# 1998  1999  text/html\t<p>\n\t\t\t<font face="Verdana" siz...
#
#                                                     raw
# 0     [Return-Path, Delivered-To, Received, Received...
# 1     [Return-Path, Delivered-To, Received, Received...
# 2     [Return-Path, Delivered-To, Received, Received...
# 3     [Return-Path, Delivered-To, Received, Received...
# 4     [Return-Path, Delivered-To, Received, Received...
# ...                                                 ...
# 1994  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1995  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1996  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1997  [Return-Path, X-Original-To, Delivered-To, Rec...
# 1998  [Return-Path, X-Original-To, Delivered-To, Rec...
#
# [1999 rows x 3 columns]
