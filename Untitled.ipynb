# %%
import pandas as pd
import pickle

# %%
df1 = pd.read_csv("resources\emails-enron.mbox-export.csv", index_col=0 )
df1
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     0
# 1         False            0          False        False          True     0
# 2         False            0          False        False          True     0
# 3         False            0          False        False          True     0
# 4         False            0          False        False          True     0
# ...         ...          ...            ...          ...           ...   ...
# 4274      False            0          False        False          True     0
# 4275      False            0          False        False          True     1
# 4276      False            0          False        False          True     0
# 4277      False            0          False        False          True     0
# 4278      False            0          False        False          True     0
#
# ...

# %%
df1['Encoding'].value_counts()
# Out:
# 7bit                4072
# quoted-printable     206
# none                   1
# Name: Encoding, dtype: int64

# %%
df2 = pd.read_csv("resources\phishing3.mbox-export.csv",index_col=0)
df2
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     2
# 1         False            0          False        False          True     2
# 2         False            0          False        False          True     2
# 3         False            0          False        False          True     3
# 4         False            0          False        False          True     3
# ...         ...          ...            ...          ...           ...   ...
# 2251      False            0          False        False          True     2
# 2252      False            0          False        False          True    32
# 2253      False            0          False        False          True     2
# 2254      False            0          False        False          True     2
# 2255      False            0          False        False          True    20
#
# ...

# %%
# df2.Encoding=df2.Encoding.replace(regex='7bit*', value='7bit')
df2.Encoding = df2.Encoding.apply(lambda x: '7bit' if '7bit' in x else x)
df2.Encoding = df2.Encoding.apply(lambda x: '8bit' if '8bit' in x else x)
df2.Encoding.value_counts()
# Out:
# none                1346
# 7bit                 735
# 8bit                 160
# quoted-printable      12
# base64                 3
# Name: Encoding, dtype: int64

# %%
df2.Encoding.value_counts()
# Out:
# none                1346
# 7bit                 735
# 8bit                 160
# quoted-printable      12
# base64                 3
# Name: Encoding, dtype: int64

# %%
df2.to_csv("resources\phishing3.mbox-export.csv")

# %%
merged_df = pd.concat([df1, df2])
merged_df.reset_index(drop=True)
# Out:
#       Html Form  Attachments  Flash content  Html iFrame  HTML content  URLs  \
# 0         False            0          False        False          True     0
# 1         False            0          False        False          True     0
# 2         False            0          False        False          True     0
# 3         False            0          False        False          True     0
# 4         False            0          False        False          True     0
# ...         ...          ...            ...          ...           ...   ...
# 6530      False            0          False        False          True     2
# 6531      False            0          False        False          True    32
# 6532      False            0          False        False          True     2
# 6533      False            0          False        False          True     2
# 6534      False            0          False        False          True    20
#
# ...

# %%
merged_df['Encoding'].value_counts()
# Out:
# 7bit                4807
# none                1347
# quoted-printable     218
# 8bit                 160
# base64                 3
# Name: Encoding, dtype: int64

# %%
merged_df.to_csv('resources\merged.csv')

# %%
pd.read_pickle('resources\emails-enron.mbox-export.pkl')

# %%
pd.read_pickle('resources\emails-enron.mbox-export.pkl')

# %%
pd.read_csv('resources\emails-enron.mbox-export.csv', index_col=0)

# %%
pd.read_csv('resources\phishing3.mbox-export.csv', index_col=0)

# %%
favorite_color = pickle.load(open('resources\phishing3.mbox-export-index.pkl', 'rb'))
favorite_color

# %%
pd.read_pickle('resources\phishing3.mbox-export-index.pkl')

# %%
print(pd.__version__)
